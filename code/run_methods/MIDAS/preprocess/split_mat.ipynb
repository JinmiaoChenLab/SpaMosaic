# %%
# Split csv matrix into csv vectors for pytorch traning
import os
import os.path as path
from os.path import join as pj
import argparse
import sys
sys.path.insert(0, '../')
sys.path.append("modules")
import modules.utils as utils
import csv
import math
from glob import glob
from tqdm import tqdm

# %%
task = 'dogma_single_full'

base_dirs = glob(pj("../data", "processed", task, "subset_*"))
for base_dir in base_dirs:
    # Specify directories
    in_dir = pj(base_dir, "mat")
    out_dir = pj(base_dir, "vec")
    utils.mkdirs(out_dir, remove_old=True)
    print("\nDirectory: %s" % (in_dir))

    # Load and save data
    mat_names = glob(pj(in_dir, '*.csv'))  # get filenames
    for i, mat_name in enumerate(mat_names):
        # load
        mat = utils.load_csv(mat_name)
        # mat = utils.transpose_list(mat)
        mod = path.splitext(path.basename(mat_name))[0]
        cell_num = len(mat) - 1
        feat_num = len(mat[0]) - 1
        print("Spliting %s matrix: %d cells, %d features" % (mod, cell_num, feat_num))
        
        # save
        out_mod_dir = pj(out_dir, mod)
        utils.mkdirs(out_mod_dir, remove_old=True)
        vec_name_fmt = utils.get_name_fmt(cell_num) + ".csv"
        vec_name_fmt = pj(out_mod_dir, vec_name_fmt)
        for cell_id in tqdm(range(cell_num)):
            vec_name = vec_name_fmt % cell_id
            utils.save_list_to_csv([mat[cell_id+1][1:]], vec_name)
# Out:
# Removing directory "../data/processed/dogma_single_full/subset_0/vec"
#
# Directory: ../data/processed/dogma_single_full/subset_0/mat
# Spliting atac matrix: 7364 cells, 27418 features
# 100%|████████████████████████████████████████████████████████████████████████| 7364/7364 [00:46<00:00, 159.99it/s]
# Removing directory "../data/processed/dogma_single_full/subset_3/vec"
#
# Directory: ../data/processed/dogma_single_full/subset_3/mat
# Spliting atac matrix: 9987 cells, 27418 features
# 100%|████████████████████████████████████████████████████████████████████████| 9987/9987 [01:03<00:00, 157.52it/s]
# Spliting rna matrix: 9987 cells, 4041 features
# 100%|████████████████████████████████████████████████████████████████████████| 9987/9987 [00:29<00:00, 339.09it/s]
# Spliting adt matrix: 9987 cells, 208 features
# 100%|████████████████████████████████████████████████████████████████████████| 9987/9987 [00:23<00:00, 433.22it/s]
# Removing directory "../data/processed/dogma_single_full/subset_1/vec"
#
# Directory: ../data/processed/dogma_single_full/subset_1/mat
# Spliting rna matrix: 5903 cells, 4041 features
# 100%|████████████████████████████████████████████████████████████████████████| 5903/5903 [00:16<00:00, 355.91it/s]
# Removing directory "../data/processed/dogma_single_full/subset_2/vec"
#
# Directory: ../data/processed/dogma_single_full/subset_2/mat
# Spliting adt matrix: 10423 cells, 208 features
# 100%|██████████████████████████████████████████████████████████████████████| 10423/10423 [00:24<00:00, 429.09it/s]

# %%
base_dirs
# Out:
# ['../data/processed/dogma_single_full/subset_0',
#  '../data/processed/dogma_single_full/subset_3',
#  '../data/processed/dogma_single_full/subset_1',
#  '../data/processed/dogma_single_full/subset_2']
